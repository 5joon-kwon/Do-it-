# %%
import numpy as np

# %%
print(np.__version__)
# Out:
# 1.25.2

# %%
ary = np.array([[1,2,3],[4,5,6]])
ary
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
type(ary)
# Out:
# numpy.ndarray

# %%
np.sum(ary)
# Out:
# 21

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4],[3,4,5,6])
plt.show()

# %%
x = np.random.randn(100) # 표준정규분포를 따르는 난수 100개 생성 -> numpy 배열
y = np.random.randn(100)
print(type(x), type(y))
plt.scatter(x,y)
plt.show()
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
